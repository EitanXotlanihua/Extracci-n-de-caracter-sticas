# %% [markdown]
# <a href="https://colab.research.google.com/github/EitanXotlanihua/Extracci-n-de-caracter-sticas/blob/main/A4_Extracci%C3%B3n_de_Caracter%C3%ADsticas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Instalamos librería para análisis de variables categóricas
# %pip install funpymodeling

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
data = pd.read_excel("microretailer_mit_lift_lab.xlsx")
data.head(5)

# %%
data1 = pd.read_excel("microretailer_mit_lift_lab.xlsx", skiprows=0)
data1

# %%
data1.info()

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(data1)

# %%
#Filtro por columnas
filtro3=data1.iloc[ : , [70,71,72,73,74,75,76,82,87,86,91,92,93,94,95,96,97,98,99,100]]
filtro3

# %%
#Ajustar maximo filas
pd.options.display.max_rows = None

# %%
#Identificaer valores nulos
seleccionados = filtro3.isnull().sum()
seleccionados
# Out:
# 42_willingness_share_inventory_data_suppliers      91
# 44_willingness_inventory_management_suppliers      92
# 45_willingness_reorder_suppliers                   94
# 46_willingness_reorder_suppliers_variety           97
# 47_willingness_reorder_suppliers_lower_prices     102
# 43_willingness_share_sales_data_suppliers         101
# 58_willingness_share_sales_data_mse               103
# 192_procurement_planning_tools                    103
# 158_charact_organize_products_on_shelves           79
# 157_frequency_organize_shelves                     75
# 249_technology_training                            98
# 250_technology_investment_operations               97
# 251_technology_investment_customers                98
# 254_technology_roadmap                            100
# 260_technology_scalable                           102
# 261_technology_organization                       102
# 262_technology_serve_customers                    100
# 263_technology_secure_sales                       101
# 264_technology_budget                             101
# 267_technology_investment_customer_preferences    101
# dtype: int64

# %% [markdown]
# **Eliminar valores nulos**

# %%
#Eliminamos valores nulos
filtro3=filtro3.fillna(method="bfill")
filtro3=filtro3.fillna(method="ffill")

# %%
#Identificaer valores nulos
seleccionados = filtro3.isnull().sum()
seleccionados
# Out:
# 42_willingness_share_inventory_data_suppliers     0
# 44_willingness_inventory_management_suppliers     0
# 45_willingness_reorder_suppliers                  0
# 46_willingness_reorder_suppliers_variety          0
# 47_willingness_reorder_suppliers_lower_prices     0
# 43_willingness_share_sales_data_suppliers         0
# 58_willingness_share_sales_data_mse               0
# 192_procurement_planning_tools                    0
# 158_charact_organize_products_on_shelves          0
# 157_frequency_organize_shelves                    0
# 249_technology_training                           0
# 250_technology_investment_operations              0
# 251_technology_investment_customers               0
# 254_technology_roadmap                            0
# 260_technology_scalable                           0
# 261_technology_organization                       0
# 262_technology_serve_customers                    0
# 263_technology_secure_sales                       0
# 264_technology_budget                             0
# 267_technology_investment_customer_preferences    0
# dtype: int64

# %%
#Corroboramos valores nulos en todo el dataframe
valores_nulos=filtro3.isnull().sum().sum()
valores_nulos

# %%
#Convertir DataFrame a CSV
filtro3.to_csv("microretailer__sin_nulos.csv")

# %%
from google.colab import files
files.download("microretailer__sin_nulos.csv")

# %% [markdown]
# **Característica con análisis univariado**

# %%
from funpymodeling.exploratory import freq_tbl

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Carga desde un archivo .xlsx sin indice
Micro_Retailer= pd.read_csv('microretailer__sin_nulos.csv')

# %%
#Imprimo los primeros 5 registro del dataframe
Micro_Retailer.head(5)

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(Micro_Retailer)
# Out:
#   42_willingness_share_inventory_data_suppliers  frequency  percentage  \
# 0                      Totalmente en desacuerdo         94    0.549708
# 1                               Algo de acuerdo         43    0.251462
# 2                            Algo en desacuerdo         15    0.087719
# 3                         Totalmente de acuerdo         12    0.070175
# 4                Ni de acuerdo ni en desacuerdo          7    0.040936
#
#    cumulative_perc
# 0         0.549708
# 1         0.801170
# 2         0.888889
# 3         0.959064
# 4         1.000000
#
# ----------------------------------------------------------------
#
#   44_willingness_inventory_management_suppliers  frequency  percentage  \
# 0                      Totalmente en desacuerdo        103    0.602339
# 1                            Algo en desacuerdo         26    0.152047
# 2                Ni de acuerdo ni en desacuerdo         16    0.093567
# 3                               Algo de acuerdo         14    0.081871
# 4                         Totalmente de acuerdo         12    0.070175
#
#    cumulative_perc
# 0         0.602339
# 1         0.754386
# 2         0.847953
# 3         0.929825
# 4         1.000000
#
# ----------------------------------------------------------------
#
#   45_willingness_reorder_suppliers  frequency  percentage  cumulative_perc
# 0         Totalmente en desacuerdo         80    0.467836         0.467836
# 1               Algo en desacuerdo         34    0.198830         0.666667
# 2            Totalmente de acuerdo         26    0.152047         0.818713
# 3                  Algo de acuerdo         22    0.128655         0.947368
# 4   Ni de acuerdo ni en desacuerdo          9    0.052632         1.000000
#
# ----------------------------------------------------------------
#
#   46_willingness_reorder_suppliers_variety  frequency  percentage  \
# 0                 Totalmente en desacuerdo         77    0.450292
# 1                    Totalmente de acuerdo         35    0.204678
# 2                       Algo en desacuerdo         24    0.140351
# 3                          Algo de acuerdo         18    0.105263
# 4           Ni de acuerdo ni en desacuerdo         17    0.099415
#
#    cumulative_perc
# 0         0.450292
# 1         0.654971
# 2         0.795322
# 3         0.900585
# 4         1.000000
#
# ----------------------------------------------------------------
#
#   47_willingness_reorder_suppliers_lower_prices  frequency  percentage  \
# 0                      Totalmente en desacuerdo         96    0.561404
# 1                               Algo de acuerdo         29    0.169591
# 2                         Totalmente de acuerdo         23    0.134503
# 3                            Algo en desacuerdo         17    0.099415
# 4                Ni de acuerdo ni en desacuerdo          6    0.035088
#
#    cumulative_perc
# 0         0.561404
# 1         0.730994
# 2         0.865497
# 3         0.964912
# 4         1.000000
#
# ----------------------------------------------------------------
#
#   43_willingness_share_sales_data_suppliers  frequency  percentage  \
# 0                  Totalmente en desacuerdo        112    0.654971
# 1                        Algo en desacuerdo         26    0.152047
# 2                           Algo de acuerdo         16    0.093567
# 3                     Totalmente de acuerdo          9    0.052632
# 4            Ni de acuerdo ni en desacuerdo          8    0.046784
#
#    cumulative_perc
# 0         0.654971
# 1         0.807018
# 2         0.900585
# 3         0.953216
# 4         1.000000
#
# ----------------------------------------------------------------
#
#   58_willingness_share_sales_data_mse  frequency  percentage  cumulative_perc
# 0            Totalmente en desacuerdo         89    0.520468         0.520468
# 1                  Algo en desacuerdo         27    0.157895         0.678363
# 2               Totalmente de acuerdo         21    0.122807         0.801170
# 3                     Algo de acuerdo         18    0.105263         0.906433
# 4      Ni de acuerdo ni en desacuerdo         16    0.093567         1.000000
#
# ----------------------------------------------------------------
#
#            192_procurement_planning_tools  frequency  percentage  \
# 0                                 Ninguna         69    0.403509
# 1                                Cuaderno         67    0.391813
# 2                  Software especializado         12    0.070175
# 3                                   Excel          7    0.040936
# 4                          Cuaderno,Excel          6    0.035088
# 5               Aplicación móvil,Cuaderno          4    0.023392
# 6   Cuaderno,Excel,Software especializado          2    0.011696
# 7                        Aplicación móvil          1    0.005848
# 8                             Mentalmente          1    0.005848
# 9                               catálogo           1    0.005848
# 10                         Compra directa          1    0.005848
#
#     cumulative_perc
# 0          0.403509
# 1          0.795322
# 2          0.865497
# 3          0.906433
# 4          0.941520
# 5          0.964912
# 6          0.976608
# 7          0.982456
# 8          0.988304
# 9          0.994152
# 10         1.000000
#
# ----------------------------------------------------------------
#
#              158_charact_organize_products_on_shelves  frequency  percentage  \
# 0   Categoría (e.g. limpieza, aseo personal, comes...         66    0.385965
# 1                                              Tamaño         28    0.163743
# 2                                 Frecuencia de venta         24    0.140351
# 3                                  Margen de utilidad         14    0.081871
# 4                                              Precio          9    0.052632
# 5                                Refrigeración,Tamaño          6    0.035088
# 6   Categoría (e.g. limpieza, aseo personal, comes...          4    0.023392
# 7                                       Refrigeración          4    0.023392
# 8                   Frecuencia de venta,Refrigeración          3    0.017544
# 9   Categoría (e.g. limpieza, aseo personal, comes...          2    0.011696
# 10  Categoría (e.g. limpieza, aseo personal, comes...          1    0.005848
# 11  Categoría (e.g. limpieza, aseo personal, comes...          1    0.005848
# 12  Categoría (e.g. limpieza, aseo personal, comes...          1    0.005848
# 13  Categoría (e.g. limpieza, aseo personal, comes...          1    0.005848
# 14  Categoría (e.g. limpieza, aseo personal, comes...          1    0.005848
# 15                                           Ninguna           1    0.005848
# 16  Categoría (e.g. limpieza, aseo personal, comes...          1    0.005848
# 17                         Frecuencia de venta,Tamaño          1    0.005848
# 18  Categoría (e.g. limpieza, aseo personal, comes...          1    0.005848
# 19                Venta cruzada (e.g. cereal + leche)          1    0.005848
# 20             Frecuencia de venta,Margen de utilidad          1    0.005848
#
#     cumulative_perc
# 0          0.385965
# 1          0.549708
# 2          0.690058
# 3          0.771930
# 4          0.824561
# 5          0.859649
# 6          0.883041
# 7          0.906433
# 8          0.923977
# 9          0.935673
# 10         0.941520
# 11         0.947368
# 12         0.953216
# 13         0.959064
# 14         0.964912
# 15         0.970760
# 16         0.976608
# 17         0.982456
# 18         0.988304
# 19         0.994152
# 20         1.000000
#
# ----------------------------------------------------------------
#
#   157_frequency_organize_shelves  frequency  percentage  cumulative_perc
# 0                   Semanalmente         73    0.426901         0.426901
# 1                    Diariamente         46    0.269006         0.695906
# 2                   Mensualmente         22    0.128655         0.824561
# 3                          Nunca         16    0.093567         0.918129
# 4                 Quincenalmente         10    0.058480         0.976608
# 5                     Anualmente          2    0.011696         0.988304
# 6                 Semestralmente          1    0.005848         0.994152
# 7                    No se tiene          1    0.005848         1.000000
#
# ----------------------------------------------------------------
#
#           249_technology_training  frequency  percentage  cumulative_perc
# 0           Totalmente de acuerdo         79    0.461988         0.461988
# 1                      De acuerdo         62    0.362573         0.824561
# 2  Ni de acuerdo ni en desacuerdo         19    0.111111         0.935673
# 3        Totalmente en desacuerdo         10    0.058480         0.994152
# 4                   En desacuerdo          1    0.005848         1.000000
#
# ----------------------------------------------------------------
#
#   250_technology_investment_operations  frequency  percentage  cumulative_perc
# 0                Totalmente de acuerdo         58    0.339181         0.339181
# 1                           De acuerdo         54    0.315789         0.654971
# 2                        En desacuerdo         35    0.204678         0.859649
# 3       Ni de acuerdo ni en desacuerdo         13    0.076023         0.935673
# 4             Totalmente en desacuerdo         11    0.064327         1.000000
#
# ----------------------------------------------------------------
#
#   251_technology_investment_customers  frequency  percentage  cumulative_perc
# 0               Totalmente de acuerdo         83    0.485380         0.485380
# 1                          De acuerdo         53    0.309942         0.795322
# 2      Ni de acuerdo ni en desacuerdo         18    0.105263         0.900585
# 3                       En desacuerdo         10    0.058480         0.959064
# 4            Totalmente en desacuerdo          7    0.040936         1.000000
#
# ----------------------------------------------------------------
#
#            254_technology_roadmap  frequency  percentage  cumulative_perc
# 0        Totalmente en desacuerdo         58    0.339181         0.339181
# 1           Totalmente de acuerdo         46    0.269006         0.608187
# 2                      De acuerdo         24    0.140351         0.748538
# 3                   En desacuerdo         22    0.128655         0.877193
# 4  Ni de acuerdo ni en desacuerdo         21    0.122807         1.000000
#
# ----------------------------------------------------------------
#
#           260_technology_scalable  frequency  percentage  cumulative_perc
# 0           Totalmente de acuerdo         63    0.368421         0.368421
# 1                      De acuerdo         50    0.292398         0.660819
# 2                   En desacuerdo         40    0.233918         0.894737
# 3  Ni de acuerdo ni en desacuerdo         12    0.070175         0.964912
# 4        Totalmente en desacuerdo          6    0.035088         1.000000
#
# ----------------------------------------------------------------
#
#       261_technology_organization  frequency  percentage  cumulative_perc
# 0           Totalmente de acuerdo         71    0.415205         0.415205
# 1                      De acuerdo         67    0.391813         0.807018
# 2        Totalmente en desacuerdo         16    0.093567         0.900585
# 3  Ni de acuerdo ni en desacuerdo         15    0.087719         0.988304
# 4                   En desacuerdo          2    0.011696         1.000000
#
# ----------------------------------------------------------------
#
#    262_technology_serve_customers  frequency  percentage  cumulative_perc
# 0           Totalmente de acuerdo         59    0.345029         0.345029
# 1                      De acuerdo         47    0.274854         0.619883
# 2        Totalmente en desacuerdo         37    0.216374         0.836257
# 3  Ni de acuerdo ni en desacuerdo         22    0.128655         0.964912
# 4                   En desacuerdo          6    0.035088         1.000000
#
# ----------------------------------------------------------------
#
#       263_technology_secure_sales  frequency  percentage  cumulative_perc
# 0                      De acuerdo         79    0.461988         0.461988
# 1           Totalmente de acuerdo         31    0.181287         0.643275
# 2  Ni de acuerdo ni en desacuerdo         27    0.157895         0.801170
# 3        Totalmente en desacuerdo         20    0.116959         0.918129
# 4                   En desacuerdo         14    0.081871         1.000000
#
# ----------------------------------------------------------------
#
#             264_technology_budget  frequency  percentage  cumulative_perc
# 0        Totalmente en desacuerdo         75    0.438596         0.438596
# 1                   En desacuerdo         38    0.222222         0.660819
# 2                      De acuerdo         22    0.128655         0.789474
# 3           Totalmente de acuerdo         18    0.105263         0.894737
# 4  Ni de acuerdo ni en desacuerdo         18    0.105263         1.000000
#
# ----------------------------------------------------------------
#
#   267_technology_investment_customer_preferences  frequency  percentage  \
# 0                          Totalmente de acuerdo         61    0.356725
# 1                                     De acuerdo         47    0.274854
# 2                       Totalmente en desacuerdo         38    0.222222
# 3                                  En desacuerdo         19    0.111111
# 4                 Ni de acuerdo ni en desacuerdo          6    0.035088
#
#    cumulative_perc
# 0         0.356725
# 1         0.631579
# 2         0.853801
# 3         0.964912
# 4         1.000000
#
# ----------------------------------------------------------------

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['42_willingness_share_inventory_data_suppliers'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('42_willingness_share_inventory_data_suppliers')
Filtro_index
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Dato de inventario provedores')
plt.xlabel('Voluntad de compartir')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Segunda grafica

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['44_willingness_inventory_management_suppliers'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('44_willingness_inventory_management_suppliers')
Filtro_index
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Gestion de inventario')
plt.xlabel('Voluntad de compartir')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **Tercera grafica**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['45_willingness_reorder_suppliers'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('45_willingness_reorder_suppliers')
Filtro_index
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Voluntad de repedir')
plt.xlabel('Voluntad de compartir')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Cuarta grafica

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['46_willingness_reorder_suppliers_variety'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('46_willingness_reorder_suppliers_variety')
Filtro_index
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Voluntad de repedir variedad')
plt.xlabel('Voluntad de compartir')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Quinta grafica

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['47_willingness_reorder_suppliers_lower_prices'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('47_willingness_reorder_suppliers_lower_prices')
Filtro_index
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Voluntad de pedir precios mas bajos')
plt.xlabel('Voluntad de compartir')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Sexta grafica

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['43_willingness_share_sales_data_suppliers'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('43_willingness_share_sales_data_suppliers')
Filtro_index
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('VCompartir datos de venta')
plt.xlabel('Voluntad de compartir')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Septima grafica

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['58_willingness_share_sales_data_mse'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('58_willingness_share_sales_data_mse')
Filtro_index
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Voluntad de compartir datos de venta')
plt.xlabel('Voluntad de compartir')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Octava grafica

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['192_procurement_planning_tools'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('192_procurement_planning_tools')
Filtro_index
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Herramientas de planificación de adquisiciones')
plt.xlabel('Herramientas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Novena grafica

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['158_charact_organize_products_on_shelves'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('158_charact_organize_products_on_shelves')
Filtro_index
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Productos en estanterias')
plt.xlabel('Categorias')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Decima grafica

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['157_frequency_organize_shelves'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('157_frequency_organize_shelves')
Filtro_index
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Frecuencia de organizacion')
plt.xlabel('Tiempo')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Undecima grafica

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['249_technology_training'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('249_technology_training')
Filtro_index
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Formacion tecnologica')
plt.xlabel('Voluntad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Decimosegunda grafica

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['250_technology_investment_operations'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('250_technology_investment_operations')
Filtro_index
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Operaciones de inversión tecnológica')
plt.xlabel('Voluntad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Decimotercera grafica

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['251_technology_investment_customers'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('251_technology_investment_customers')
Filtro_index
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Inversion de clientes')
plt.xlabel('Voluntad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Decimocuarta grafica

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['254_technology_roadmap'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('254_technology_roadmap')
Filtro_index
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Plano tecnologico')
plt.xlabel('Voluntad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Decimoquinta grafica

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['260_technology_scalable'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('260_technology_scalable')
Filtro_index
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Tecnología escalable')
plt.xlabel('Voluntad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Decimosexta grafica

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['261_technology_organization'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('261_technology_organization')
Filtro_index
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Organización tecnológica')
plt.xlabel('Voluntad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Decimoseptima grafica

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['262_technology_serve_customers'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('262_technology_serve_customers')
Filtro_index
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Organización tecnológica')
plt.xlabel('Voluntad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Decimooctava grafica

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['263_technology_secure_sales'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('263_technology_secure_sales')
Filtro_index
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Ventas tecnologias seguras')
plt.xlabel('Voluntad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Decimo novena grafica

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['264_technology_budget'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('264_technology_budget')
Filtro_index
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Presupuesto en tecnología')
plt.xlabel('Voluntad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Vigesimo

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['267_technology_investment_customer_preferences'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('267_technology_investment_customer_preferences')
Filtro_index
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Preferenciaas del cliente')
plt.xlabel('Voluntad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
